# %%
import pandas as pd
# data = pd.read_csv('D:/ShipSupplies/DA/data/raw.csv')
data = pd.read_csv('../data/raw.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24667 entries, 0 to 24666
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assembly     24664 non-null  object
#  1   Control No.  15465 non-null  object
#  2   D/T          22335 non-null  object
#  3   Machinery    24664 non-null  object
#  4   No.          24664 non-null  float64
#  5   Part No.1    24640 non-null  object
#  6   Subject      24642 non-null  object
#  7   견적           24200 non-null  object
#  8   견적단가         24664 non-null  float64
#  9   견적수량         24546 non-null  float64
#  10  견적화폐         24546 non-null  object
#  11  발주           24546 non-null  object
#  12  발주금액         24549 non-null  float64
#  13  발주번호         24664 non-null  object
#  14  발주수량         24546 non-null  float64
#  15  발주처          24546 non-null  object
#  16  선박입고수량       24664 non-null  float64
#  17  입고창고         21345 non-null  object
# ...

# %%
data.count()
# Out:
# Assembly       24664
# Control No.    15465
# D/T            22335
# Machinery      24664
# No.            24664
# Part No.1      24640
# Subject        24642
# 견적             24200
# 견적단가           24664
# 견적수량           24546
# 견적화폐           24546
# 발주             24546
# 발주금액           24549
# 발주번호           24664
# 발주수량           24546
# 발주처            24546
# 선박입고수량         24664
# 입고창고           21345
# 창고입고           21345
# 창고입고수량         24664
# 창고출고           19277
# 창고출고수량         24664
# 청구량            24546
# 청구서번호          24664
# 청구품목           24664
# 출고선박           19277
# 출고운반선          19277
# dtype: int64

# %%
df = data.fillna(0)

# %%
# head
df.head()
# Out:
#         Assembly Control No. D/T                         Machinery  No.
# 0          BLOCK   19-04-077  56    CARGO BOOM VANG BLOCK (STBD 하)  1.0  \
# 1          BLOCK   19-04-064  56  SPANISH BOOM VANG BLOCK (PORT 상)  2.0
# 2      TOW BLOCK   19-04-077  56                       PURSE BLOCK  3.0
# 3  POWER PACK AS           0  60                       MAIN ENGINE  1.0
# 4  POWER PACK AS           0  60                       MAIN ENGINE  2.0
#
#                 Part No.1               Subject          견적     견적단가  견적수량
# 0                C15S10BS  COK-F-DECK-190104-01  2019-01-11  1022.76   2.0  \
# 1                C15D10BS  COK-F-DECK-190104-01  2019-01-11  1713.96   1.0
# 2  WESTEC 20TON TOW BLOCK  COK-F-DECK-190104-01  2019-01-11  5843.75   1.0
# 3                40028340              폰페이 재고정정  2019-04-01  4000.00   8.0
# 4                40028340              폰페이 재고정정  2019-04-01  4000.00   8.0
#
#    ... 입고창고        창고입고  창고입고수량        창고출고  창고출고수량  청구량               청구서번호
# ...

# %%
# column정보
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24667 entries, 0 to 24666
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assembly     24667 non-null  object
#  1   Control No.  24667 non-null  object
#  2   D/T          24667 non-null  object
#  3   Machinery    24667 non-null  object
#  4   No.          24667 non-null  float64
#  5   Part No.1    24667 non-null  object
#  6   Subject      24667 non-null  object
#  7   견적           24667 non-null  object
#  8   견적단가         24667 non-null  float64
#  9   견적수량         24667 non-null  float64
#  10  견적화폐         24667 non-null  object
#  11  발주           24667 non-null  object
#  12  발주금액         24667 non-null  float64
#  13  발주번호         24667 non-null  object
#  14  발주수량         24667 non-null  float64
#  15  발주처          24667 non-null  object
#  16  선박입고수량       24667 non-null  float64
#  17  입고창고         24667 non-null  object
# ...

# %%
df.isna().count().sum()
# Out:
# 666009

# %%
import numpy as np

temp1 = df[(df['발주'] == 0) | (df['창고입고'] == 0)] # 발주날짜와 입고 날짜가 없는 데이터
idx = temp1.index
temp1
df1 = df.drop(idx)  # 삭제

df1 = df1.reset_index() # 인덱스 초기화
df1 = df1.drop('index', axis=1) # index 열 삭제

df1
# Out:
#                                         Assembly Control No. D/T
# 0                                          BLOCK   19-04-077  56  \
# 1                                          BLOCK   19-04-064  56
# 2                                      TOW BLOCK   19-04-077  56
# 3                                  POWER PACK AS           0  60
# 4                                  POWER PACK AS           0  60
# ...                                          ...         ...  ..
# 21222  CRANKSHAFT, FLYWHEEL AND VIBRATION DAMPER   22-06-135  35
# 21223  CRANKSHAFT, FLYWHEEL AND VIBRATION DAMPER   22-06-135  35
# 21224      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
# 21225      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
# 21226      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
#
#                               Machinery  No.               Part No.1
# 0        CARGO BOOM VANG BLOCK (STBD 하)  1.0                C15S10BS  \
# ...

# %%
df1['발주'] = pd.to_datetime(df1['발주'])
df1['창고입고'] = pd.to_datetime(df1['창고입고'])

# %%
# df1.info()
df1.columns
# Out:
# Index(['Assembly', 'Control No.', 'D/T', 'Machinery', 'No.', 'Part No.1',
#        'Subject', '견적', '견적단가', '견적수량', '견적화폐', '발주', '발주금액', '발주번호', '발주수량',
#        '발주처', '선박입고수량', '입고창고', '창고입고', '창고입고수량', '창고출고', '창고출고수량', '청구량',
#        '청구서번호', '청구품목', '출고선박', '출고운반선'],
#       dtype='object')

# %%
df1['leadtime'] =  df1['창고입고'] - df1['발주']

# %%
# int로 형변환
df1['leadtime'] = df1['leadtime'].apply(lambda x: x.days)
df1['leadtime']
# Out:
# 0        112
# 1         97
# 2        112
# 3          0
# 4          0
#         ...
# 21222     88
# 21223     88
# 21224     88
# 21225     88
# 21226     88
# Name: leadtime, Length: 21227, dtype: int64

# %%
t = df1[df1['leadtime'] < 0]
t.index
df1 = df1.drop(t.index)
df1 = df1.reset_index() # 인덱스 초기화
df1 = df1.drop('index', axis=1) # index 열 삭제
df1
# Out:
#                                         Assembly Control No. D/T
# 0                                          BLOCK   19-04-077  56  \
# 1                                          BLOCK   19-04-064  56
# 2                                      TOW BLOCK   19-04-077  56
# 3                                  POWER PACK AS           0  60
# 4                                  POWER PACK AS           0  60
# ...                                          ...         ...  ..
# 20853  CRANKSHAFT, FLYWHEEL AND VIBRATION DAMPER   22-06-135  35
# 20854  CRANKSHAFT, FLYWHEEL AND VIBRATION DAMPER   22-06-135  35
# 20855      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
# 20856      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
# 20857      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
#
#                               Machinery  No.               Part No.1
# 0        CARGO BOOM VANG BLOCK (STBD 하)  1.0                C15S10BS  \
# ...

# %%
df1
# Out:
#                                         Assembly Control No. D/T
# 0                                          BLOCK   19-04-077  56  \
# 1                                          BLOCK   19-04-064  56
# 2                                      TOW BLOCK   19-04-077  56
# 3                                  POWER PACK AS           0  60
# 4                                  POWER PACK AS           0  60
# ...                                          ...         ...  ..
# 20853  CRANKSHAFT, FLYWHEEL AND VIBRATION DAMPER   22-06-135  35
# 20854  CRANKSHAFT, FLYWHEEL AND VIBRATION DAMPER   22-06-135  35
# 20855      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
# 20856      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
# 20857      AIR FILTER WITH SILENCER INSTALLATION   22-06-135  35
#
#                               Machinery  No.               Part No.1
# 0        CARGO BOOM VANG BLOCK (STBD 하)  1.0                C15S10BS  \
# ...

# %% [markdown]
# df_product = df1["Assembly", "Control No." "Machinery" Part No.1 발주처]

# %%
df_product = df1[["발주처", "청구품목", 'leadtime',"Assembly" ,"Machinery" ,"Part No.1"]]
df_product
# Out:
#                              발주처
# 0      MATSUI(U.S.A) COROPRATION  \
# 1      MATSUI(U.S.A) COROPRATION
# 2      MATSUI(U.S.A) COROPRATION
# 3      MATSUI(U.S.A) COROPRATION
# 4      MATSUI(U.S.A) COROPRATION
# ...                          ...
# 20853          yusinHR Co., Ltd.
# 20854          yusinHR Co., Ltd.
# 20855          yusinHR Co., Ltd.
# 20856          yusinHR Co., Ltd.
# 20857          yusinHR Co., Ltd.
#
#                                                    청구품목  leadtime
# 0      MCKISSICK CONSTRUCTION BLOCKS (WIRE SIZE : 5/8")       112  \
# 1      MCKISSICK CONSTRUCTION BLOCKS (WIRE SIZE : 5/8")        97
# 2                                WESTEC 20TON TOW BLOCK       112
# 3                            GE POWER PACK FORK - E7(B)         0
# 4                            GE POWER PACK FORK - E7(B)         0
# ...                                                 ...       ...
# 20853                    WIRE LOCKING, 42751 IN DIA            88
# ...

# %%
df1.to_csv('../data/raw_postpro2.csv',index=False, encoding='utf-8-sig')

# %%
# from sqlalchemy import create_engine
# import pymysql
# import pandas as pd
# db_connection_str = 'mysql+pymysql://root:qwer1234@localhost/upbit'
# db_connection = create_engine(db_connection_str)
# conn = db_connection.connect()
# df_bitcoin.to_sql(name='upbit', con=db_connection, if_exists='append',index=False)

# %%
import pandas as pd
from sqlalchemy import create_engine

# MySQL 서버에 연결
engine = create_engine('mysql+mysqlconnector://root:1234@localhost:3306/project')

# 데이터프레임을 MySQL 데이터베이스에 저장
df_product.to_sql(name='product', con=engine, if_exists='replace', index=False)
# Out:
# 20858
